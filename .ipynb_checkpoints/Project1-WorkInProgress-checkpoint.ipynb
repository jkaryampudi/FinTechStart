# %%
# Initial imports
import os
import requests
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi

# %matplotlib inline

# %%
# Load .env environment variables
load_dotenv()
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# %%
type(alpaca_api_key)
type(alpaca_secret_key)
# Out:
# str

# %%
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
# Format current date as ISO format
start_date = pd.Timestamp("2016-11-17", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2021-11-17", tz="America/New_York").isoformat()

# %%
# Set timeframe to one day ('1D') for the Alpaca API
timeframe = "1D"
ticker_stock_1 = ["AMZN"]
ticker_stock_2 = ["TSLA"]

# %%
# Get current price data for AMZN
df_price_stock_1 = alpaca.get_barset(
    ticker_stock_1,
    timeframe,
    start = start_date,
    end = end_date
).df

# Display sample data
df_price_stock_1
# Out:
#                                AMZN
#                                open       high        low    close   volume
# time
# 2021-06-29 00:00:00-04:00  3440.000  3456.0300  3423.0300  3449.48  1696088
# 2021-06-30 00:00:00-04:00  3443.000  3471.6018  3435.0000  3440.29  1959873
# 2021-07-01 00:00:00-04:00  3436.000  3457.0000  3409.4207  3432.98  1801106
# 2021-07-02 00:00:00-04:00  3451.500  3511.7200  3436.9200  3510.99  2711182
# 2021-07-06 00:00:00-04:00  3530.110  3685.4800  3529.0000  3675.72  6394617
# ...                             ...        ...        ...      ...      ...
# 2021-11-11 00:00:00-05:00  3514.740  3543.2400  3467.4700  3472.46  2087255
# 2021-11-12 00:00:00-05:00  3488.890  3540.7263  3447.0500  3525.97  2316171
# 2021-11-15 00:00:00-05:00  3538.045  3593.8800  3525.8100  3545.69  2370404
# 2021-11-16 00:00:00-05:00  3539.000  3576.5000  3525.1465  3540.70  1878273
# 2021-11-17 00:00:00-05:00  3565.950  3587.2450  3545.3500  3548.86  2332560
#
# [100 rows x 5 columns]

# %%
# Create and empty DataFrame for closing prices
df_closing_stock_1 = pd.DataFrame()

# Fetch the closing prices for all the tickers
for ticker in ticker_stock_1:
    df_closing_stock_1[ticker] = df_price_stock_1[ticker]["close"]

# Drop the time component of the date
df_closing_stock_1.index = df_closing_stock_1.index.date

# Display sample data
df_closing_stock_1.head()
# Out:
#                AMZN
# 2021-06-29  3449.48
# 2021-06-30  3440.29
# 2021-07-01  3432.98
# 2021-07-02  3510.99
# 2021-07-06  3675.72

# %%
# Count nulls
df_price_stock_1.isnull().sum()
# Out:
# AMZN  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# dtype: int64

# %%
# Calculate the summary statistics of key points of stock
df_stock_1_summary = df_price_stock_1.describe()
df_stock_1_summary
# Out:
#               AMZN
#               open         high          low        close        volume
# count   100.000000   100.000000   100.000000   100.000000  1.000000e+02
# mean   3426.572200  3459.277282  3396.055167  3429.112476  2.810383e+06
# std     136.378575   140.312672   132.993403   137.335639  1.125003e+06
# min    3196.760000  3207.810000  3175.760000  3186.470000  1.457942e+06
# 25%    3317.145000  3350.424950  3291.710000  3315.837500  2.120783e+06
# 50%    3397.215000  3442.640000  3382.575000  3423.851500  2.539101e+06
# 75%    3514.992500  3550.045000  3477.827500  3512.402500  3.087084e+06
# max    3743.500000  3773.078100  3696.793000  3731.420000  9.183755e+06

# %%
# Compute daily returns
df_daily_returns_stock_1 = df_closing_stock_1.pct_change().dropna()

# Display sample data
df_daily_returns_stock_1.head()
# Out:
#                 AMZN
# 2021-06-30 -0.002664
# 2021-07-01 -0.002125
# 2021-07-02  0.022724
# 2021-07-06  0.046918
# 2021-07-07  0.006195

# %%
# Visualize the distribution of daily returns across all stocks using a histogram plot
# Hint: To make the plot easier to read, set the alpha arguement to 0.5
df_daily_returns_stock_1.plot.hist(alpha=0.5,bins=[-0.75,-0.5,-0.25,0,0.25,0.5,0.75])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_daily_returns_stock_1.plot.hist(alpha=0.5,bins=[-0.25,-0.20,-0.15,-0.10,-0.05,0,0.05,0.10,0.15,0.20,0.25])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Visualize the distribution of daily returns across stock using a density plot
df_daily_returns_stock_1.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_daily_returns_stock_1.plot(title = "Daily Returns", figsize = (10,6))
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}>

# %%
# Calculate cumulative returns
cumulative_return = (1 + df_daily_returns_stock_1).cumprod()

# Plot cumulative returns
cumulative_return.plot(title='Cumulative Daily Returns', figsize = (10,6))
# Out:
# <AxesSubplot:title={'center':'Cumulative Daily Returns'}>

# %%
# Box plot to visually show risk
df_daily_returns_stock_1.plot(kind = "box", title = 'Portfolio Risk', figsize = (10,6))
# Out:
# <AxesSubplot:title={'center':'Portfolio Risk'}>

# %%
# Calculate the daily standard deviations of all portfolios
df_daily_std = df_daily_returns_stock_1.std().sort_values(ascending=True)
df_daily_std
# Out:
# AMZN    0.015239
# dtype: float64

# %%
# Calculate the daily return summary statistics
df_daily_std = df_daily_returns_stock_1.describe()
df_daily_std
# Out:
#             AMZN
# count  99.000000
# mean    0.000403
# std     0.015239
# min    -0.075683
# 25%    -0.005343
# 50%     0.000672
# 75%     0.009040
# max     0.046918

# %%
# Calculate the annualized standard deviation (252 trading days)
df_annualized_std = df_daily_std * np.sqrt(252)
df_annualized_std
# Out:
#               AMZN
# count  1571.576279
# mean      0.006400
# std       0.241906
# min      -1.201436
# 25%      -0.084822
# 50%       0.010664
# 75%       0.143510
# max       0.744806

# %%
# Calculate the rolling Mean for the stock using a 21-day window
stock1_rolling_mean_21days = df_daily_returns_stock_1.rolling(window = 21).mean().dropna()
stock1_rolling_mean_21days
# Out:
#                 AMZN
# 2021-07-29  0.002137
# 2021-07-30 -0.001341
# 2021-08-02 -0.001181
# 2021-08-03 -0.001759
# 2021-08-04 -0.004166
# ...              ...
# 2021-11-11  0.002790
# 2021-11-12  0.003308
# 2021-11-15  0.001996
# 2021-11-16  0.001416
# 2021-11-17  0.001547
#
# [79 rows x 1 columns]

# %%
stock1_rolling_mean_21days.plot(title="Stock's 21 Day Rolling Mean", figsize = (10,6))
# Out:
# <AxesSubplot:title={'center':"Stock's 21 Day Rolling Mean"}>

# %%
# Calculate the rolling standard deviation for the stock using a 21-day window
stock1_rolling_std_21days = df_daily_returns_stock_1.rolling(window = 21).std().dropna()
stock1_rolling_std_21days
# Out:
#                 AMZN
# 2021-07-29  0.014584
# 2021-07-30  0.022397
# 2021-08-02  0.022403
# 2021-08-03  0.021906
# 2021-08-04  0.018855
# ...              ...
# 2021-11-11  0.017380
# 2021-11-12  0.017596
# 2021-11-15  0.016235
# 2021-11-16  0.016122
# 2021-11-17  0.016118
#
# [79 rows x 1 columns]

# %%
stock1_rolling_std_21days.plot(title="Stock's 21 Day Rolling Standard Deviation", figsize = (10,6))
# Out:
# <AxesSubplot:title={'center':"Stock's 21 Day Rolling Standard Deviation"}>

# %%
# Get current price data for AMZN
df_price_stock_2 = alpaca.get_barset(
    ticker_stock_2,
    timeframe,
    start = start_date,
    end = end_date
).df

# Display sample data
df_price_stock_2.head()
# Out:
#                              TSLA
#                              open      high       low   close    volume
# time
# 2021-06-29 00:00:00-04:00  684.65  687.5099  675.8900  680.76  16629908
# 2021-06-30 00:00:00-04:00  679.86  692.8100  678.1400  679.78  17501754
# 2021-07-01 00:00:00-04:00  684.00  687.9900  672.8000  677.92  17652563
# 2021-07-02 00:00:00-04:00  679.00  700.0000  673.2600  678.90  25565649
# 2021-07-06 00:00:00-04:00  681.80  684.0000  651.4002  659.49  21785768

# %%
# Create and empty DataFrame for closing prices
df_closing_stock_2 = pd.DataFrame()

# Fetch the closing prices for all the tickers
for ticker in ticker_stock_2:
    df_closing_stock_2[ticker] = df_price_stock_2[ticker]["close"]

# Drop the time component of the date
df_closing_stock_2.index = df_closing_stock_2.index.date

# Compute daily returns
df_daily_returns_stock_2 = df_closing_stock_2.pct_change().dropna()

# Display sample data
df_daily_returns_stock_2.head()
# Out:
#                 TSLA
# 2021-06-30 -0.001440
# 2021-07-01 -0.002736
# 2021-07-02  0.001446
# 2021-07-06 -0.028590
# 2021-07-07 -0.022199

# %%
# Join stock 1 & 2  daily returns into a single DataFrame with columns for each stocks daily returns.
combined_daily = pd.concat([df_daily_returns_stock_1, df_daily_returns_stock_2], axis = "columns", join = "inner")
combined_daily_return = combined_daily.dropna()
combined_daily_return
# Out:
#                 AMZN      TSLA
# 2021-06-30 -0.002664 -0.001440
# 2021-07-01 -0.002125 -0.002736
# 2021-07-02  0.022724  0.001446
# 2021-07-06  0.046918 -0.028590
# 2021-07-07  0.006195 -0.022199
# ...              ...       ...
# 2021-11-11 -0.002770 -0.003980
# 2021-11-12  0.015410 -0.028218
# 2021-11-15  0.005593 -0.019168
# 2021-11-16 -0.001407  0.040298
# 2021-11-17  0.002305  0.033057
#
# [99 rows x 2 columns]

# %%
# Plot daily returns of all compared stock
combined_daily_return.plot(title = "Daily Returns", figsize = (10,6))
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}>

# %%
# Calculate cumulative returns of compared stocks
combined_cumulative_return = (1 + combined_daily_return).cumprod()

# Plot cumulative returns
combined_cumulative_return.plot(title='Cumulative Returns', figsize = (10,6))
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}>

# %%
# Calculate the correlation between each stock to determine if stock mimick each other
correlation = combined_daily_return.corr()
correlation
# Out:
#           AMZN      TSLA
# AMZN  1.000000 -0.046835
# TSLA -0.046835  1.000000

# %%
# Plot the correlation
sns.heatmap(correlation, vmin=-1, vmax=1,annot=True)
## NOTE: The closer 'r' is to 1, the stronger the positive association between two quantitive variables
# Out:
# <AxesSubplot:>

# %%
# Calculate covariance of a compared stock
stock1_stock2_rolling_covariance = combined_daily_return['AMZN'].rolling(window=60).cov(combined_daily_return['TSLA']).dropna()
stock1_stock2_rolling_covariance.head()
# Out:
# 2021-09-23    0.000035
# 2021-09-24    0.000036
# 2021-09-27    0.000034
# 2021-09-28    0.000043
# 2021-09-29    0.000069
# dtype: float64

# %%
# Calculate variance of AMZN
stock1_stock2_rolling_variance = combined_daily_return['AMZN'].rolling(window=60).var().dropna()
stock1_stock2_rolling_variance.head()
# Out:
# 2021-09-23    0.000237
# 2021-09-24    0.000237
# 2021-09-27    0.000238
# 2021-09-28    0.000240
# 2021-09-29    0.000201
# Name: AMZN, dtype: float64

# %%
# Computing beta
stock1_stock2_beta = stock1_stock2_rolling_covariance / stock1_stock2_rolling_variance
stock1_stock2_beta.head()
# Out:
# 2021-09-23    0.147674
# 2021-09-24    0.152617
# 2021-09-27    0.143512
# 2021-09-28    0.181088
# 2021-09-29    0.343269
# dtype: float64

# %%
# Plot beta trend
stock1_stock2_beta_plot = stock1_stock2_beta.plot(title="AMAZON beta value to TSLA", figsize=(10, 6))

# %%
# Use `ewm` to calculate the rolling window
rolling_window_ewm = combined_daily_return.ewm(halflife=21, adjust=True).std().plot(title="Exponentialy Weighted Average", figsize=(20, 10))
rolling_window_ewm
# Out:
# <AxesSubplot:title={'center':'Exponentialy Weighted Average'}>

# %%
# Annualized Sharpe Ratios
sharpe_ratio = (combined_daily_return.mean() * 252) / (combined_daily_return.std() * np.sqrt(252))
sharpe_ratio
# Out:
# AMZN    0.419984
# TSLA    2.919782
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>
